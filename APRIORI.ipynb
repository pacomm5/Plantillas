# %% [markdown]
# <a href="https://colab.research.google.com/github/pacomm5/Plantillas/blob/main/APRIORI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clonamos el repositorio para obtener los dataSet

# %%
#!git clone https://github.com/joanby/machinelearning-az.git
! git clone https://github.com/pacomm5/machinelearning-az
# Out:
# Cloning into 'machinelearning-az'...
# remote: Enumerating objects: 10541, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 10541 (delta 25), reused 0 (delta 0), pack-reused 10505
# Receiving objects: 100% (10541/10541), 311.58 MiB | 26.68 MiB/s, done.
# Resolving deltas: 100% (245/245), done.
# Checking out files: 100% (10250/10250), done.

# %% [markdown]
# # Damos acceso a nuestro Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Test it

# %%
# !ls '/content/drive/My Drive'

# %% [markdown]
# #Google colab tools

# %%
from google.colab import files # Para manejar los archivos y, por ejemplo, exportar a su navegador
import glob # Para manejar los archivos y, por ejemplo, exportar a su navegador
from google.colab import drive # Montar tu Google drive

# %% [markdown]
# #Instalar dependendias

# %%
# !pip install sklearn

# %% [markdown]
# # Regresión Bosques Aleatorios

# %% [markdown]
# # Cómo importar las librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importar el data set

# %%
dataset = pd.read_csv("/content/machinelearning-az/datasets/Part 5 - Association Rule Learning/Section 28 - Apriori/Apriori_Python/Market_Basket_Optimisation.csv", header=None)
# 20 columnas y 7501 filas. NO tiene header. 7501 cestas de la compra. y 20 artículos. 
# como vemos el primero se ha llevado de todo....

# %%
dataset.head(5)
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
# modificamos el dataframe. le vamos a dar una estructura. le vamos a dar el formato correcto a cada fila. 
# vamos a crear una lista de listas. 

transactions = [] # incializimos la lista vacía. 
for i in range(0, 7501): # recorre todas las filas. 7501 que es hasta 7500
    transactions.append([str(dataset.values[i, j]) for j in range(0,20)]) # para cada fila i, valor j que lo coge del for j in range 0,20 
    
# lo cambia a string

# %%
transactions # es una lista de listas
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers',
#   'meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chutney',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'avocado',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
# ...

# %% [markdown]
# # Entrenar el algoritmo de Apriori

# %%
# !pip install apyori
from apyori import apriori

# %%
rules = apriori(transactions, min_support = 0.003 , min_confidence = 0.2,
                min_lift = 3, min_length = 2) # minimo de dos productos, soporte mínimo (con que presencia minima tiene que estar)
# min support minimo 3 veces al día. 3 x 7 = 21, que aparezce en al menos 21 cestas 21/7500 estos es 0,003

# %% [markdown]
# # Visualización de los resultados

# %%
results = list(rules)

print(results[4])
# Out:
# RelationRecord(items=frozenset({'ground beef', 'herb & pepper'}), support=0.015997866951073192, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herb & pepper'}), items_add=frozenset({'ground beef'}), confidence=0.3234501347708895, lift=3.2919938411349285)])

# %%
results[1]
# Out:
# RelationRecord(items=frozenset({'mushroom cream sauce', 'escalope'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)])

# %%
# la salsa de champiñon aparece el 0,0057 de las cestas, y en un 30% van junto con escalope

# %%
results[2]
# Out:
# RelationRecord(items=frozenset({'escalope', 'pasta'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)])

# %%
# el escalope con la pasta en un 37% de las ocasiones. el lift bastante elevado.
